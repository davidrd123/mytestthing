# %%
#| hide
from mytestthing.core import *

# %% [markdown]
# # mytestthing
#
# > It's just a test thing

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install mytestthing in Development mode

# %% [markdown]
# ```sh
# # make sure mytestthing package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to mytestthing
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/davidrd123/mytestthing.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c davidrd123 mytestthing
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install mytestthing
# ```
#
#
# [repo]: https://github.com/davidrd123/mytestthing
# [docs]: https://davidrd123.github.io/mytestthing/
# [pypi]: https://pypi.org/project/mytestthing/
# [conda]: https://anaconda.org/davidrd123/mytestthing

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/davidrd123/mytestthing
# [docs]: https://davidrd123.github.io/mytestthing/
# [pypi]: https://pypi.org/project/mytestthing/
# [conda]: https://anaconda.org/davidrd123/mytestthing

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
